# %% [markdown]
# <a href="https://colab.research.google.com/github/habeebalsaqaf/rdp/blob/main/model_training_with_pyWeka3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install build-essential python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# python3-dev is already the newest version (3.10.6-1~22.04).
# python3-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !sudo apt install python3-pip python3-numpy python3-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools python3-setuptools-whl python3-wheel
#   python3.10-venv
# Suggested packages:
#   python-numpy-doc python3-pytest python-setuptools-doc
# The following NEW packages will be installed:
#   python3-numpy python3-pip python3-pip-whl python3-setuptools
#   python3-setuptools-whl python3-venv python3-wheel python3.10-venv
# 0 upgraded, 8 newly installed, 0 to remove and 45 not upgraded.
# Need to get 7,618 kB of archives.
# After this operation, 30.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# ...

# %%
# !sudo apt install python3-pil python3-matplotlib python3-pygraphviz libgraphviz-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-lyx libgail-common libgail18 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgvc6-plugins-gtk libimagequant0 liblbfgsb0
#   libraqm0 librsvg2-common libxdot4 libxsimd-dev mailcap mime-support
#   python-matplotlib-data python3-appdirs python3-attr python3-beniget
#   python3-brotli python3-bs4 python3-chardet python3-cycler python3-dateutil
#   python3-decorator python3-fonttools python3-fs python3-gast python3-html5lib
#   python3-kiwisolver python3-lxml python3-lz4 python3-mpmath python3-olefile
#   python3-packaging python3-pil.imagetk python3-ply python3-pythran
#   python3-scipy python3-soupsieve python3-sympy python3-tz python3-ufolib2
#   python3-unicodedata2 python3-webencodings unicode-data
# Suggested packages:
#   gvfs libxsimd-doc python-attr-doc python-cycler-doc python3-genshi
# ...

# %%
# !sudo apt install openjdk-11-jdk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libice-dev libsm-dev libxkbfile1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-11-jre x11-utils
# Suggested packages:
#   libice-doc libsm-doc libxt-doc openjdk-11-demo openjdk-11-source visualvm
#   mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libice-dev libsm-dev libxkbfile1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-11-jdk openjdk-11-jre x11-utils
# 0 upgraded, 13 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,476 kB of archives.
# After this operation, 12.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# ...

# %%
# !python3 -m venv pww3

# %%
# !. ./pww3/bin/activate
# !pip install setuptools wheel
# !pip install python-weka-wrapper3[plots,graphs]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 39.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 25.9 MB/s eta 0:00:00
# ...
#   Created wheel for configurable-objects: filename=configurable_objects-0.0.1-py3-none-any.whl size=4696 sha256=631065f3ef4ec4d77b066ddbb36f960d8423fe9ee7fbdb06e9b1bceaf1697ffd
#   Stored in directory: /root/.cache/pip/wheels/ef/11/bc/75ac8b0592c38dc42412942c37d3947faf0b222bad150132a1
# ...
#   Created wheel for python-weka-wrapper3: filename=python_weka_wrapper3-0.3.2-py3-none-any.whl size=14495850 sha256=4c040280e6e3956c8b36382f9698f53041fbc163a7fb84ab4bcf5eb2ad9e4e58
#   Stored in directory: /root/.cache/pip/wheels/67/6c/8b/ac3ddbec2fff91bdbedc52d8f6bdc2199bcec5338002f164ed
# ...

# %%
import weka.core.jvm as jvm
from weka.core.converters import Loader
from weka.classifiers import Classifier, Evaluation
from weka.core.classes import Random

# بدء JVM
jvm.start()

# تحميل البيانات
loader = Loader(classname="weka.core.converters.ArffLoader")
data = loader.load_file("/content/pww3/iris.arff")
data.class_is_last()

# تقسيم البيانات إلى 70% للتدريب و 30% للاختبار
train, test = data.train_test_split(70.0, Random(1))

# إنشاء نموذج J48
classifier = Classifier(classname="weka.classifiers.trees.J48")
classifier.build_classifier(train)

# تقييم النموذج
evaluation = Evaluation(train)
evaluation.test_model(classifier, test)

# عرض النتائج
print(evaluation.summary())
print(evaluation.class_details())
x=evaluation.confusion_matrix
print(x)

# إيقاف JVM
jvm.stop()
# Out:
# DEBUG:weka.core.jvm:Adding bundled jars
# DEBUG:weka.core.jvm:Classpath=['/usr/local/lib/python3.10/dist-packages/weka/lib/core.jar', '/usr/local/lib/python3.10/dist-packages/weka/lib/arpack_combined.jar', '/usr/local/lib/python3.10/dist-packages/weka/lib/python-weka-wrapper.jar', '/usr/local/lib/python3.10/dist-packages/weka/lib/mtj.jar', '/usr/local/lib/python3.10/dist-packages/weka/lib/weka.jar']
# DEBUG:weka.core.jvm:MaxHeapSize=default
# DEBUG:weka.core.jvm:Package support disabled
# Correctly Classified Instances          43               95.5556 %
# Incorrectly Classified Instances         2                4.4444 %
# Kappa statistic                          0.9331
# Mean absolute error                      0.0416
# Root mean squared error                  0.1682
# Relative absolute error                  9.3466 %
# Root relative squared error             35.6559 %
# Total Number of Instances               45
#
# === Detailed Accuracy By Class ===
#
# ...
